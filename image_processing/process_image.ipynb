# %% [markdown]
# <a href="https://colab.research.google.com/github/emm-gl/project_mna/blob/main/image_processing/process_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from PIL import Image

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Defined functions:

# %%
def crop_images_in_directory(input_directory, output_directory, crop_box):
    """
    Crop all image files in the specified input directory using the provided crop box coordinates.

    Parameters:
        input_directory (str): Path to the directory containing the input image files.
        output_directory (str): Path to the directory where cropped images will be saved.
        crop_box (tuple): A tuple (left, top, right, bottom) specifying the cropping box.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # List all files in the input directory
    files = os.listdir(input_directory)

    # Filter out only image files
    image_files = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

    # Crop each image file
    for image_file in image_files:
        input_image_path = os.path.join(input_directory, image_file)
        output_image_path = os.path.join(output_directory, image_file)
        crop_image(input_image_path, output_image_path, crop_box)

def crop_image(input_image_path, output_image_path, crop_box):
    """
    Crop an image using the provided crop box coordinates.

    Parameters:
        input_image_path (str): Path to the input image file.
        output_image_path (str): Path to save the cropped image.
        crop_box (tuple): A tuple (left, top, right, bottom) specifying the cropping box.
    """
    # Open the input image
    img = Image.open(input_image_path)

    # Crop the image using the specified crop box
    cropped_img = img.crop(crop_box)

    # Save the cropped image
    cropped_img.save(output_image_path)

# %%
import os
from PIL import Image

def convert_to_grayscale(input_directory, output_directory):
    """
    Convert all images in the specified input directory to grayscale and save them in the output directory.

    Parameters:
        input_directory (str): Path to the directory containing the input image files.
        output_directory (str): Path to the directory where grayscale images will be saved.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # List all files in the input directory
    files = os.listdir(input_directory)

    # Filter out only image files
    image_files = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

    # Convert each image file to grayscale
    for image_file in image_files:
        input_image_path = os.path.join(input_directory, image_file)
        output_image_path = os.path.join(output_directory, image_file)
        convert_image_to_grayscale(input_image_path, output_image_path)

def convert_image_to_grayscale(input_image_path, output_image_path):
    """
    Convert an image to grayscale.

    Parameters:
        input_image_path (str): Path to the input image file.
        output_image_path (str): Path to save the grayscale image.
    """
    # Open the input image
    img = Image.open(input_image_path)

    # Convert the image to grayscale
    grayscale_img = img.convert("L")

    # Save the grayscale image
    grayscale_img.save(output_image_path)

# %% [markdown]
# ###Process images:

# %%
# Cropp images:
input_directory = "/content/drive/My Drive/final_project/OK_drives_images"
output_directory = "/content/drive/My Drive/final_project/ok_images_cropped"
crop_box = (55, 18, 1222, 620)  # Example crop box (left, top, right, bottom)

crop_images_in_directory(input_directory, output_directory, crop_box)

# %%
#Convert color images to grayscale

# Example usage
input_directory = "/content/drive/My Drive/final_project/ok_images_cropped"
output_directory = "/content/drive/My Drive/final_project/ok_images_cropped_grayscale"

convert_to_grayscale(input_directory, output_directory)

# %% [markdown]
# ###testings

# %%
#Visualization of the box on image

from PIL import Image, ImageDraw

# Open the image
path = "/content/drive/My Drive/final_project/test/01.Page1.png"
image = Image.open(path)

# Create a drawing object
draw = ImageDraw.Draw(image)

# Define the coordinates of the box
box_coordinates = [(55, 18), (1222, 620)]  # Format: [(x1, y1), (x2, y2)]

# Draw the box on the image
draw.rectangle(box_coordinates, outline="red", width=3)

# Save or display the modified image
image.show()
display(image)
#image.save("image_with_box.jpg")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x672>

# %%
width, height = image.size
print(image.size)
# Out:
# (1226, 672)
