# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

import random
     
from keras.layers import Dropout
from keras.layers import Flatten

from tensorflow.keras.layers import Conv2D

from tensorflow.keras.layers import MaxPooling2D
     
from keras.models import Model

import matplotlib.image as mpimg
import seaborn as sns
import cv2

import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, average_precision_score
# Out:
# 2024-06-02 17:42:48.152409: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
file_path = 'Desktop/proyecto integrador/*'

# %%
#Data acquisition
noise = glob.glob("train/OK_500/*.png")

nonoise = glob.glob("train/NOK_500/*.png")

# %%
len(noise)
# Out:
# 500

# %%
len(nonoise)
# Out:
# 500

# %%
noise_Formated = []
nonoise_Formated = []

width = 400 
height = 250
dim = (width, height)

for i in noise:
    img_gray = mpimg.imread(i)
    #resize image
    img_resized = cv2.resize(img_gray, dim, interpolation = cv2.INTER_AREA)
    
    #add the new image to a new array
    noise_Formated.append(img_resized)

for i in nonoise:
    img_gray = mpimg.imread(i)
    #resize image
    img_resized = cv2.resize(img_gray, dim, interpolation = cv2.INTER_AREA)
    
    #add the new image to a new array
    nonoise_Formated.append(img_resized)

# %%
y_noise = np.ones(len(noise_Formated))
y_nonoise = np.zeros(len(nonoise_Formated))

# %%
X = np.vstack((noise_Formated,nonoise_Formated))
X.shape
# Out:
# (1000, 250, 400)

# %%
y = np.hstack((y_noise,y_nonoise))
y.shape
# Out:
# (1000,)

# %%
X=X/255

# %%
# 400 x 250 = 100,000
num_pixels = 100000
X = X.reshape(X.shape[0], num_pixels)
print(X.shape)
# Out:
# (1000, 100000)

# %%
model = Sequential()
model.add(Dense(units = 50, input_dim=num_pixels, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 25, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 12, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=1, input_dim=100000, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │     5,000,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │           312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,001,650 (19.08 MB)
#  Trainable params: 5,001,650 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
print(X.shape)
print(y.shape)
print(np.random.choice(y,10,replace=True))
# Out:
# (1000, 100000)
# (1000,)
# [1. 1. 0. 0. 0. 1. 0. 0. 1. 0.]

# %%
# 10% para el set de prueba
X_tv, X_test, y_tv, y_test = train_test_split(X, y, test_size = 0.1, stratify=y, random_state = 42)

# %%
# 10% para el set de validacion
X_train, X_val, y_train, y_val = train_test_split(X_tv, y_tv, test_size = 0.1, stratify=y_tv, random_state = 42)

# %%
hist = model.fit(x=X_train, y=y_train, verbose=2, batch_size=32, epochs=100, 
                 validation_data=(X_val, y_val), shuffle='true')
# Out:
# Epoch 1/100
# 26/26 - 8s - 293ms/step - accuracy: 0.5840 - loss: 0.6789 - val_accuracy: 0.6889 - val_loss: 0.6487
# Epoch 2/100
# 26/26 - 3s - 114ms/step - accuracy: 0.6148 - loss: 0.6552 - val_accuracy: 0.6889 - val_loss: 0.6208
# Epoch 3/100
# 26/26 - 3s - 117ms/step - accuracy: 0.6642 - loss: 0.6203 - val_accuracy: 0.6667 - val_loss: 0.5933
# Epoch 4/100
# 26/26 - 3s - 112ms/step - accuracy: 0.6704 - loss: 0.6001 - val_accuracy: 0.6778 - val_loss: 0.5896
# Epoch 5/100
# 26/26 - 3s - 97ms/step - accuracy: 0.6877 - loss: 0.5884 - val_accuracy: 0.7111 - val_loss: 0.5637
# Epoch 6/100
# 26/26 - 3s - 113ms/step - accuracy: 0.7321 - loss: 0.5586 - val_accuracy: 0.7333 - val_loss: 0.5577
# Epoch 7/100
# 26/26 - 3s - 99ms/step - accuracy: 0.7222 - loss: 0.5522 - val_accuracy: 0.7111 - val_loss: 0.5473
# Epoch 8/100
# 26/26 - 2s - 86ms/step - accuracy: 0.7198 - loss: 0.5452 - val_accuracy: 0.7000 - val_loss: 0.5415
# Epoch 9/100
# 26/26 - 2s - 87ms/step - accuracy: 0.7247 - loss: 0.5468 - val_accuracy: 0.7556 - val_loss: 0.5366
# Epoch 10/100
# 26/26 - 3s - 104ms/step - accuracy: 0.7407 - loss: 0.5224 - val_accuracy: 0.7111 - val_loss: 0.5311
# Epoch 11/100
# 26/26 - 2s - 86ms/step - accuracy: 0.7642 - loss: 0.5118 - val_accuracy: 0.7333 - val_loss: 0.5399
# Epoch 12/100
# 26/26 - 2s - 86ms/step - accuracy: 0.7494 - loss: 0.5376 - val_accuracy: 0.7222 - val_loss: 0.5470
# Epoch 13/100
# 26/26 - 2s - 91ms/step - accuracy: 0.7605 - loss: 0.5131 - val_accuracy: 0.7667 - val_loss: 0.5103
# Epoch 14/100
# 26/26 - 2s - 86ms/step - accuracy: 0.7691 - loss: 0.4817 - val_accuracy: 0.7667 - val_loss: 0.5026
# Epoch 15/100
# 26/26 - 2s - 93ms/step - accuracy: 0.7630 - loss: 0.4821 - val_accuracy: 0.8000 - val_loss: 0.4952
# Epoch 16/100
# 26/26 - 2s - 91ms/step - accuracy: 0.7938 - loss: 0.4658 - val_accuracy: 0.7333 - val_loss: 0.5153
# Epoch 17/100
# 26/26 - 3s - 119ms/step - accuracy: 0.7938 - loss: 0.4552 - val_accuracy: 0.7333 - val_loss: 0.4989
# Epoch 18/100
# 26/26 - 4s - 171ms/step - accuracy: 0.7728 - loss: 0.4769 - val_accuracy: 0.8111 - val_loss: 0.4838
# Epoch 19/100
# 26/26 - 3s - 114ms/step - accuracy: 0.8074 - loss: 0.4478 - val_accuracy: 0.8000 - val_loss: 0.4717
# Epoch 20/100
# 26/26 - 3s - 109ms/step - accuracy: 0.8210 - loss: 0.4152 - val_accuracy: 0.8222 - val_loss: 0.4571
# Epoch 21/100
# 26/26 - 3s - 96ms/step - accuracy: 0.8259 - loss: 0.3901 - val_accuracy: 0.8333 - val_loss: 0.4586
# Epoch 22/100
# 26/26 - 2s - 90ms/step - accuracy: 0.8395 - loss: 0.3790 - val_accuracy: 0.8111 - val_loss: 0.4667
# Epoch 23/100
# 26/26 - 2s - 87ms/step - accuracy: 0.8593 - loss: 0.3592 - val_accuracy: 0.8222 - val_loss: 0.4542
# Epoch 24/100
# 26/26 - 3s - 114ms/step - accuracy: 0.8444 - loss: 0.3656 - val_accuracy: 0.8222 - val_loss: 0.4532
# Epoch 25/100
# 26/26 - 4s - 153ms/step - accuracy: 0.8679 - loss: 0.3322 - val_accuracy: 0.8111 - val_loss: 0.4586
# Epoch 26/100
# 26/26 - 3s - 115ms/step - accuracy: 0.8667 - loss: 0.3267 - val_accuracy: 0.7889 - val_loss: 0.4527
# Epoch 27/100
# 26/26 - 3s - 97ms/step - accuracy: 0.8852 - loss: 0.3128 - val_accuracy: 0.8111 - val_loss: 0.4111
# Epoch 28/100
# 26/26 - 2s - 85ms/step - accuracy: 0.8901 - loss: 0.2719 - val_accuracy: 0.8000 - val_loss: 0.4211
# Epoch 29/100
# 26/26 - 2s - 89ms/step - accuracy: 0.9173 - loss: 0.2487 - val_accuracy: 0.8556 - val_loss: 0.3908
# Epoch 30/100
# 26/26 - 4s - 141ms/step - accuracy: 0.9309 - loss: 0.2271 - val_accuracy: 0.8444 - val_loss: 0.3794
# Epoch 31/100
# 26/26 - 3s - 128ms/step - accuracy: 0.9123 - loss: 0.2349 - val_accuracy: 0.8556 - val_loss: 0.3610
# Epoch 32/100
# 26/26 - 3s - 128ms/step - accuracy: 0.8938 - loss: 0.2560 - val_accuracy: 0.8778 - val_loss: 0.3652
# Epoch 33/100
# 26/26 - 4s - 141ms/step - accuracy: 0.9111 - loss: 0.2309 - val_accuracy: 0.8778 - val_loss: 0.3364
# Epoch 34/100
# 26/26 - 2s - 89ms/step - accuracy: 0.9383 - loss: 0.1920 - val_accuracy: 0.8667 - val_loss: 0.3560
# Epoch 35/100
# 26/26 - 3s - 103ms/step - accuracy: 0.9395 - loss: 0.1737 - val_accuracy: 0.8778 - val_loss: 0.3195
# Epoch 36/100
# 26/26 - 3s - 110ms/step - accuracy: 0.9370 - loss: 0.1852 - val_accuracy: 0.8889 - val_loss: 0.3336
# Epoch 37/100
# 26/26 - 4s - 160ms/step - accuracy: 0.9531 - loss: 0.1668 - val_accuracy: 0.8667 - val_loss: 0.3717
# Epoch 38/100
# 26/26 - 4s - 140ms/step - accuracy: 0.9506 - loss: 0.1450 - val_accuracy: 0.8778 - val_loss: 0.3495
# Epoch 39/100
# 26/26 - 3s - 115ms/step - accuracy: 0.9593 - loss: 0.1285 - val_accuracy: 0.8889 - val_loss: 0.3591
# Epoch 40/100
# 26/26 - 3s - 119ms/step - accuracy: 0.9580 - loss: 0.1455 - val_accuracy: 0.8778 - val_loss: 0.3582
# Epoch 41/100
# 26/26 - 3s - 99ms/step - accuracy: 0.9556 - loss: 0.1482 - val_accuracy: 0.8889 - val_loss: 0.3691
# Epoch 42/100
# 26/26 - 2s - 94ms/step - accuracy: 0.9741 - loss: 0.1112 - val_accuracy: 0.9000 - val_loss: 0.3107
# Epoch 43/100
# 26/26 - 3s - 98ms/step - accuracy: 0.9728 - loss: 0.1121 - val_accuracy: 0.9000 - val_loss: 0.3188
# Epoch 44/100
# 26/26 - 3s - 98ms/step - accuracy: 0.9654 - loss: 0.1115 - val_accuracy: 0.9000 - val_loss: 0.3104
# Epoch 45/100
# 26/26 - 3s - 101ms/step - accuracy: 0.9704 - loss: 0.1064 - val_accuracy: 0.9222 - val_loss: 0.2808
# Epoch 46/100
# 26/26 - 2s - 95ms/step - accuracy: 0.9617 - loss: 0.1082 - val_accuracy: 0.9333 - val_loss: 0.2582
# Epoch 47/100
# 26/26 - 2s - 96ms/step - accuracy: 0.9765 - loss: 0.0937 - val_accuracy: 0.8889 - val_loss: 0.3443
# Epoch 48/100
# 26/26 - 3s - 111ms/step - accuracy: 0.9765 - loss: 0.0849 - val_accuracy: 0.8556 - val_loss: 0.3741
# Epoch 49/100
# 26/26 - 5s - 184ms/step - accuracy: 0.9444 - loss: 0.1396 - val_accuracy: 0.9111 - val_loss: 0.3207
# Epoch 50/100
# 26/26 - 3s - 114ms/step - accuracy: 0.9630 - loss: 0.0904 - val_accuracy: 0.9111 - val_loss: 0.2948
# Epoch 51/100
# 26/26 - 3s - 111ms/step - accuracy: 0.9654 - loss: 0.0951 - val_accuracy: 0.9111 - val_loss: 0.3171
# Epoch 52/100
# 26/26 - 6s - 216ms/step - accuracy: 0.9815 - loss: 0.0655 - val_accuracy: 0.9111 - val_loss: 0.2715
# Epoch 53/100
# 26/26 - 5s - 178ms/step - accuracy: 0.9864 - loss: 0.0596 - val_accuracy: 0.9333 - val_loss: 0.3016
# Epoch 54/100
# 26/26 - 5s - 186ms/step - accuracy: 0.9753 - loss: 0.0753 - val_accuracy: 0.9222 - val_loss: 0.2941
# Epoch 55/100
# 26/26 - 4s - 160ms/step - accuracy: 0.9840 - loss: 0.0581 - val_accuracy: 0.9222 - val_loss: 0.2947
# Epoch 56/100
# 26/26 - 3s - 122ms/step - accuracy: 0.9815 - loss: 0.0568 - val_accuracy: 0.9222 - val_loss: 0.3166
# Epoch 57/100
# 26/26 - 3s - 107ms/step - accuracy: 0.9877 - loss: 0.0354 - val_accuracy: 0.9222 - val_loss: 0.2856
# Epoch 58/100
# 26/26 - 3s - 98ms/step - accuracy: 0.9864 - loss: 0.0477 - val_accuracy: 0.9000 - val_loss: 0.3060
# Epoch 59/100
# 26/26 - 2s - 91ms/step - accuracy: 0.9852 - loss: 0.0497 - val_accuracy: 0.9222 - val_loss: 0.3048
# Epoch 60/100
# 26/26 - 2s - 91ms/step - accuracy: 0.9827 - loss: 0.0552 - val_accuracy: 0.9000 - val_loss: 0.3561
# Epoch 61/100
# 26/26 - 2s - 89ms/step - accuracy: 0.9778 - loss: 0.0738 - val_accuracy: 0.9222 - val_loss: 0.2896
# Epoch 62/100
# 26/26 - 2s - 93ms/step - accuracy: 0.9765 - loss: 0.0721 - val_accuracy: 0.9111 - val_loss: 0.2708
# Epoch 63/100
# 26/26 - 2s - 95ms/step - accuracy: 0.9889 - loss: 0.0424 - val_accuracy: 0.9444 - val_loss: 0.2683
# Epoch 64/100
# 26/26 - 2s - 86ms/step - accuracy: 0.9951 - loss: 0.0236 - val_accuracy: 0.9111 - val_loss: 0.3073
# Epoch 65/100
# 26/26 - 2s - 88ms/step - accuracy: 0.9901 - loss: 0.0326 - val_accuracy: 0.9333 - val_loss: 0.2912
# Epoch 66/100
# 26/26 - 2s - 84ms/step - accuracy: 0.9852 - loss: 0.0355 - val_accuracy: 0.9333 - val_loss: 0.3105
# Epoch 67/100
# 26/26 - 3s - 103ms/step - accuracy: 0.9988 - loss: 0.0194 - val_accuracy: 0.9444 - val_loss: 0.3181
# Epoch 68/100
# 26/26 - 2s - 86ms/step - accuracy: 0.9877 - loss: 0.0368 - val_accuracy: 0.9222 - val_loss: 0.3729
# Epoch 69/100
# 26/26 - 2s - 84ms/step - accuracy: 0.9889 - loss: 0.0465 - val_accuracy: 0.9333 - val_loss: 0.3165
# Epoch 70/100
# 26/26 - 2s - 84ms/step - accuracy: 0.9963 - loss: 0.0223 - val_accuracy: 0.9444 - val_loss: 0.3247
# Epoch 71/100
# 26/26 - 2s - 90ms/step - accuracy: 0.9926 - loss: 0.0261 - val_accuracy: 0.9333 - val_loss: 0.3087
# Epoch 72/100
# 26/26 - 2s - 87ms/step - accuracy: 0.9975 - loss: 0.0174 - val_accuracy: 0.9333 - val_loss: 0.3163
# Epoch 73/100
# 26/26 - 2s - 87ms/step - accuracy: 0.9988 - loss: 0.0199 - val_accuracy: 0.9333 - val_loss: 0.3490
# Epoch 74/100
# 26/26 - 2s - 83ms/step - accuracy: 0.9914 - loss: 0.0275 - val_accuracy: 0.9222 - val_loss: 0.3267
# Epoch 75/100
# 26/26 - 2s - 83ms/step - accuracy: 0.9926 - loss: 0.0279 - val_accuracy: 0.9333 - val_loss: 0.3328
# Epoch 76/100
# 26/26 - 3s - 107ms/step - accuracy: 0.9914 - loss: 0.0287 - val_accuracy: 0.9333 - val_loss: 0.3132
# Epoch 77/100
# 26/26 - 3s - 96ms/step - accuracy: 0.9889 - loss: 0.0333 - val_accuracy: 0.8889 - val_loss: 0.4550
# Epoch 78/100
# 26/26 - 3s - 110ms/step - accuracy: 0.9864 - loss: 0.0435 - val_accuracy: 0.9333 - val_loss: 0.3308
# Epoch 79/100
# 26/26 - 2s - 93ms/step - accuracy: 0.9864 - loss: 0.0413 - val_accuracy: 0.9111 - val_loss: 0.3973
# Epoch 80/100
# 26/26 - 2s - 88ms/step - accuracy: 0.9370 - loss: 0.1971 - val_accuracy: 0.8667 - val_loss: 0.4471
# Epoch 81/100
# 26/26 - 2s - 86ms/step - accuracy: 0.9642 - loss: 0.1178 - val_accuracy: 0.9000 - val_loss: 0.3436
# Epoch 82/100
# 26/26 - 2s - 90ms/step - accuracy: 0.9852 - loss: 0.0577 - val_accuracy: 0.9222 - val_loss: 0.2567
# Epoch 83/100
# 26/26 - 2s - 82ms/step - accuracy: 0.9840 - loss: 0.0577 - val_accuracy: 0.9444 - val_loss: 0.2789
# Epoch 84/100
# 26/26 - 2s - 83ms/step - accuracy: 0.9963 - loss: 0.0280 - val_accuracy: 0.9222 - val_loss: 0.2825
# Epoch 85/100
# 26/26 - 2s - 87ms/step - accuracy: 0.9938 - loss: 0.0349 - val_accuracy: 0.9444 - val_loss: 0.2772
# Epoch 86/100
# 26/26 - 2s - 87ms/step - accuracy: 0.9901 - loss: 0.0411 - val_accuracy: 0.8778 - val_loss: 0.4047
# Epoch 87/100
# 26/26 - 3s - 96ms/step - accuracy: 0.9642 - loss: 0.0817 - val_accuracy: 0.7667 - val_loss: 0.7109
# Epoch 88/100
# 26/26 - 2s - 87ms/step - accuracy: 0.8778 - loss: 0.3150 - val_accuracy: 0.8778 - val_loss: 0.3194
# Epoch 89/100
# 26/26 - 3s - 101ms/step - accuracy: 0.9321 - loss: 0.1541 - val_accuracy: 0.9333 - val_loss: 0.2678
# Epoch 90/100
# 26/26 - 3s - 104ms/step - accuracy: 0.9420 - loss: 0.1578 - val_accuracy: 0.9222 - val_loss: 0.2473
# Epoch 91/100
# 26/26 - 3s - 132ms/step - accuracy: 0.9593 - loss: 0.1016 - val_accuracy: 0.9111 - val_loss: 0.2972
# Epoch 92/100
# 26/26 - 3s - 117ms/step - accuracy: 0.9444 - loss: 0.1239 - val_accuracy: 0.9222 - val_loss: 0.2428
# Epoch 93/100
# 26/26 - 3s - 108ms/step - accuracy: 0.9506 - loss: 0.1157 - val_accuracy: 0.9111 - val_loss: 0.2907
# Epoch 94/100
# 26/26 - 3s - 108ms/step - accuracy: 0.9568 - loss: 0.1050 - val_accuracy: 0.9000 - val_loss: 0.3145
# Epoch 95/100
# 26/26 - 3s - 117ms/step - accuracy: 0.9593 - loss: 0.1050 - val_accuracy: 0.9111 - val_loss: 0.2410
# Epoch 96/100
# 26/26 - 3s - 124ms/step - accuracy: 0.9642 - loss: 0.0833 - val_accuracy: 0.9333 - val_loss: 0.2433
# Epoch 97/100
# 26/26 - 5s - 204ms/step - accuracy: 0.9691 - loss: 0.0750 - val_accuracy: 0.9333 - val_loss: 0.2457
# Epoch 98/100
# 26/26 - 3s - 125ms/step - accuracy: 0.9765 - loss: 0.0765 - val_accuracy: 0.9444 - val_loss: 0.2818
# Epoch 99/100
# 26/26 - 3s - 130ms/step - accuracy: 0.9728 - loss: 0.0724 - val_accuracy: 0.9333 - val_loss: 0.2670
# Epoch 100/100
# 26/26 - 3s - 126ms/step - accuracy: 0.9753 - loss: 0.0629 - val_accuracy: 0.9222 - val_loss: 0.2577

# %%
# resumen del model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │     5,000,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 12)             │           312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,004,952 (57.24 MB)
#  Trainable params: 5,001,650 (19.08 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 10,003,302 (38.16 MB)

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)
# Out:
# 4/4 - 0s - 24ms/step - accuracy: 0.9400 - loss: 0.2405

# %%
# Obtén los datos del historial
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

loss = hist.history['loss']
val_loss = hist.history['val_loss']


# Gráfica de accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()

# Gráfica de pérdida
plt.subplot(1, 2, 2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# Ajusta los márgenes y espacios entre subplots
plt.tight_layout()

# Muestra las gráficas
plt.show()

# %%
y_proba_train = model.predict(X_train)
y_pred_train = y_proba_train.round().astype(int)
y_proba_validation = model.predict(X_val)
y_pred_validation = y_proba_validation.round().astype(int)
y_proba_test = model.predict(X_test)
y_pred_test = y_proba_test.round().astype(int)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
lbl = LabelEncoder()
target_names = ['class 0', 'class 1']
#Class 0 = NOK
#Class 1 = OK

# %%
# !pip install -q scikit-plot
import scikitplot as skplt

# %%
print("Train sample \n", classification_report(y_train, y_pred_train,target_names = target_names))
print("Validation sample \n", classification_report(y_val, y_pred_validation,target_names = target_names))
print("Test sample \n", classification_report(y_test, y_pred_test,target_names = target_names))
# Out:
# Train sample
#                precision    recall  f1-score   support
#
#      class 0       1.00      0.98      0.99       405
#      class 1       0.98      1.00      0.99       405
#
#     accuracy                           0.99       810
#    macro avg       0.99      0.99      0.99       810
# weighted avg       0.99      0.99      0.99       810
#
# Validation sample
#                precision    recall  f1-score   support
#
#      class 0       0.91      0.93      0.92        45
#      class 1       0.93      0.91      0.92        45
#
#     accuracy                           0.92        90
#    macro avg       0.92      0.92      0.92        90
# weighted avg       0.92      0.92      0.92        90
#
# Test sample
#                precision    recall  f1-score   support
#
#      class 0       0.94      0.94      0.94        50
#      class 1       0.94      0.94      0.94        50
#
#     accuracy                           0.94       100
#    macro avg       0.94      0.94      0.94       100
# weighted avg       0.94      0.94      0.94       100

# %%
# Gráfico de Matriz de Confusión
skplt.metrics.plot_confusion_matrix(y_train, y_pred_train, normalize=True)
plt.title('Matriz de Confusión Train')

skplt.metrics.plot_confusion_matrix(y_val, y_pred_validation, normalize=True)
plt.title('Matriz de Confusión Validation')

skplt.metrics.plot_confusion_matrix(y_test, y_pred_test, normalize=True)
plt.title('Matriz de Confusión Test')

plt.show()

# %%
#taza de verdaderos positivos y taza de falsos positivos 
fpr, tpr, thresholds =  roc_curve(y_val, y_pred_validation)

#AUC 
auc = roc_auc_score(y_val, y_pred_validation)

plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Curva ROC (area = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taza de Falsos Positivos')
plt.ylabel('Taza de Verdaderos Positivos')
plt.title('Caracteristica Operativa del Receptor (CURVA ROC)\n Validacion')

plt.legend(loc="lower right")
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

skplt.metrics.plot_roc(y_train, np.column_stack((1-y_pred_train, y_pred_train)), ax=axes[0])
axes[0].set_title("Muestra train")

skplt.metrics.plot_roc(y_test, np.column_stack((1-y_pred_test, y_pred_test)), ax=axes[1])
axes[1].set_title("Muestra test")

skplt.metrics.plot_roc(y_val, np.column_stack((1-y_pred_validation, y_pred_validation)), ax=axes[2])
axes[2].set_title("Muestra validation")
axes[2].legend(loc="lower right")

# %%
#calcular la curva pr
precision, recall, thresholds = precision_recall_curve(y_val, y_pred_validation)

auc_pr = average_precision_score(y_val, y_pred_validation)

plt.figure()
plt.plot(recall, precision, color='blue', lw=2, label=f'Curva Precision-Recall (area = {auc_pr:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva de Precision-Recall\n Validacion')

plt.legend(loc="lower right")
plt.show()

# %%
#guardar archivo de modelo ya entrenado
target_dir = './modelo_keras_noise4/'
if not os.path.exists(target_dir):
    os.mkdir(target_dir)
model.save('./modelo_keras_noise4/modelo_keras_noise4.keras')
model.save_weights('./modelo_keras_noise4/pesos.weights.h5')
