# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

import random
     
from keras.layers import Dropout
from keras.layers import Flatten

from tensorflow.keras.layers import Conv2D

from tensorflow.keras.layers import MaxPooling2D
     
from keras.models import Model

import matplotlib.image as mpimg
import seaborn as sns
import cv2

import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, precision_recall_curve, average_precision_score
# Out:
# 2024-06-02 17:52:16.042673: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
file_path = 'Desktop/proyecto integrador/*'

# %%
#Data acquisition
noise = glob.glob("train/OK_500/*.png")

nonoise = glob.glob("train/NOK_500/*.png")

# %%
len(noise)
# Out:
# 500

# %%
len(nonoise)
# Out:
# 500

# %%
noise_Formated = []
nonoise_Formated = []

width = 400 
height = 250
dim = (width, height)

for i in noise:
    img_gray = mpimg.imread(i)
    #resize image
    img_resized = cv2.resize(img_gray, dim, interpolation = cv2.INTER_AREA)
    
    #add the new image to a new array
    noise_Formated.append(img_resized)

for i in nonoise:
    img_gray = mpimg.imread(i)
    #resize image
    img_resized = cv2.resize(img_gray, dim, interpolation = cv2.INTER_AREA)
    
    #add the new image to a new array
    nonoise_Formated.append(img_resized)

# %%
y_noise = np.ones(len(noise_Formated))
y_nonoise = np.zeros(len(nonoise_Formated))

# %%
X = np.vstack((noise_Formated,nonoise_Formated))
X.shape
# Out:
# (1000, 250, 400)

# %%
y = np.hstack((y_noise,y_nonoise))
y.shape
# Out:
# (1000,)

# %%
X=X/255

# %%
# 400 x 250 = 100,000
num_pixels = 100000
X = X.reshape(X.shape[0], num_pixels)
print(X.shape)
# Out:
# (1000, 100000)

# %%
model = Sequential()
model.add(Dense(units = 64, input_dim=num_pixels, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 16, activation='softmax'))
model.add(Dropout(0.2))
model.add(Dense(units=1, input_dim=100000, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │     6,400,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,402,689 (24.42 MB)
#  Trainable params: 6,402,689 (24.42 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
print(X.shape)
print(y.shape)
print(np.random.choice(y,10,replace=True))
# Out:
# (1000, 100000)
# (1000,)
# [0. 1. 0. 0. 1. 0. 1. 0. 1. 0.]

# %%
# 10% para el set de prueba
X_tv, X_test, y_tv, y_test = train_test_split(X, y, test_size = 0.1, stratify=y, random_state = 42)

# %%
# 10% para el set de validacion
X_train, X_val, y_train, y_val = train_test_split(X_tv, y_tv, test_size = 0.1, stratify=y_tv, random_state = 42)

# %%
hist = model.fit(x=X_train, y=y_train, verbose=2, batch_size=32, epochs=100, 
                 validation_data=(X_val, y_val), shuffle='true')
# Out:
# Epoch 1/100
# 26/26 - 9s - 363ms/step - accuracy: 0.5037 - loss: 0.6923 - val_accuracy: 0.5444 - val_loss: 0.6877
# Epoch 2/100
# 26/26 - 3s - 123ms/step - accuracy: 0.6123 - loss: 0.6819 - val_accuracy: 0.6667 - val_loss: 0.6718
# Epoch 3/100
# 26/26 - 4s - 144ms/step - accuracy: 0.6593 - loss: 0.6600 - val_accuracy: 0.6778 - val_loss: 0.6425
# Epoch 4/100
# 26/26 - 3s - 132ms/step - accuracy: 0.6519 - loss: 0.6467 - val_accuracy: 0.6889 - val_loss: 0.6294
# Epoch 5/100
# 26/26 - 3s - 110ms/step - accuracy: 0.6728 - loss: 0.6320 - val_accuracy: 0.7000 - val_loss: 0.6180
# Epoch 6/100
# 26/26 - 3s - 117ms/step - accuracy: 0.6901 - loss: 0.6190 - val_accuracy: 0.7111 - val_loss: 0.6086
# Epoch 7/100
# 26/26 - 3s - 103ms/step - accuracy: 0.7198 - loss: 0.6144 - val_accuracy: 0.7000 - val_loss: 0.6071
# Epoch 8/100
# 26/26 - 3s - 105ms/step - accuracy: 0.7012 - loss: 0.6141 - val_accuracy: 0.7222 - val_loss: 0.5996
# Epoch 9/100
# 26/26 - 3s - 104ms/step - accuracy: 0.7123 - loss: 0.6018 - val_accuracy: 0.7222 - val_loss: 0.5942
# Epoch 10/100
# 26/26 - 3s - 107ms/step - accuracy: 0.7235 - loss: 0.5983 - val_accuracy: 0.7667 - val_loss: 0.5890
# Epoch 11/100
# 26/26 - 3s - 112ms/step - accuracy: 0.7210 - loss: 0.5973 - val_accuracy: 0.7333 - val_loss: 0.5820
# Epoch 12/100
# 26/26 - 3s - 99ms/step - accuracy: 0.7395 - loss: 0.5844 - val_accuracy: 0.7667 - val_loss: 0.5755
# Epoch 13/100
# 26/26 - 3s - 113ms/step - accuracy: 0.7284 - loss: 0.5903 - val_accuracy: 0.7556 - val_loss: 0.5739
# Epoch 14/100
# 26/26 - 3s - 128ms/step - accuracy: 0.7469 - loss: 0.5764 - val_accuracy: 0.7667 - val_loss: 0.5713
# Epoch 15/100
# 26/26 - 3s - 100ms/step - accuracy: 0.7506 - loss: 0.5749 - val_accuracy: 0.8000 - val_loss: 0.5663
# Epoch 16/100
# 26/26 - 3s - 101ms/step - accuracy: 0.7358 - loss: 0.5725 - val_accuracy: 0.7222 - val_loss: 0.5831
# Epoch 17/100
# 26/26 - 3s - 117ms/step - accuracy: 0.7432 - loss: 0.5877 - val_accuracy: 0.7667 - val_loss: 0.5595
# Epoch 18/100
# 26/26 - 3s - 98ms/step - accuracy: 0.7519 - loss: 0.5649 - val_accuracy: 0.7889 - val_loss: 0.5572
# Epoch 19/100
# 26/26 - 3s - 101ms/step - accuracy: 0.7654 - loss: 0.5609 - val_accuracy: 0.8111 - val_loss: 0.5479
# Epoch 20/100
# 26/26 - 3s - 101ms/step - accuracy: 0.7691 - loss: 0.5551 - val_accuracy: 0.8000 - val_loss: 0.5445
# Epoch 21/100
# 26/26 - 3s - 108ms/step - accuracy: 0.7617 - loss: 0.5469 - val_accuracy: 0.8111 - val_loss: 0.5390
# Epoch 22/100
# 26/26 - 3s - 101ms/step - accuracy: 0.7765 - loss: 0.5437 - val_accuracy: 0.8111 - val_loss: 0.5342
# Epoch 23/100
# 26/26 - 3s - 118ms/step - accuracy: 0.7728 - loss: 0.5334 - val_accuracy: 0.8000 - val_loss: 0.5353
# Epoch 24/100
# 26/26 - 3s - 119ms/step - accuracy: 0.7975 - loss: 0.5320 - val_accuracy: 0.8222 - val_loss: 0.5286
# Epoch 25/100
# 26/26 - 3s - 117ms/step - accuracy: 0.8111 - loss: 0.5094 - val_accuracy: 0.7000 - val_loss: 0.5645
# Epoch 26/100
# 26/26 - 3s - 115ms/step - accuracy: 0.7716 - loss: 0.5285 - val_accuracy: 0.8000 - val_loss: 0.5181
# Epoch 27/100
# 26/26 - 3s - 119ms/step - accuracy: 0.8025 - loss: 0.5177 - val_accuracy: 0.8333 - val_loss: 0.5155
# Epoch 28/100
# 26/26 - 3s - 129ms/step - accuracy: 0.8000 - loss: 0.5149 - val_accuracy: 0.8000 - val_loss: 0.5110
# Epoch 29/100
# 26/26 - 3s - 134ms/step - accuracy: 0.8136 - loss: 0.5000 - val_accuracy: 0.8000 - val_loss: 0.5116
# Epoch 30/100
# 26/26 - 3s - 111ms/step - accuracy: 0.8259 - loss: 0.4839 - val_accuracy: 0.8222 - val_loss: 0.5027
# Epoch 31/100
# 26/26 - 3s - 103ms/step - accuracy: 0.8123 - loss: 0.5017 - val_accuracy: 0.8222 - val_loss: 0.5000
# Epoch 32/100
# 26/26 - 3s - 104ms/step - accuracy: 0.8407 - loss: 0.4714 - val_accuracy: 0.7222 - val_loss: 0.5361
# Epoch 33/100
# 26/26 - 3s - 102ms/step - accuracy: 0.8148 - loss: 0.4850 - val_accuracy: 0.8111 - val_loss: 0.4963
# Epoch 34/100
# 26/26 - 3s - 100ms/step - accuracy: 0.8321 - loss: 0.4711 - val_accuracy: 0.8111 - val_loss: 0.4982
# Epoch 35/100
# 26/26 - 3s - 107ms/step - accuracy: 0.8383 - loss: 0.4637 - val_accuracy: 0.8222 - val_loss: 0.4941
# Epoch 36/100
# 26/26 - 3s - 107ms/step - accuracy: 0.8432 - loss: 0.4499 - val_accuracy: 0.8222 - val_loss: 0.4864
# Epoch 37/100
# 26/26 - 3s - 102ms/step - accuracy: 0.8617 - loss: 0.4384 - val_accuracy: 0.8222 - val_loss: 0.4837
# Epoch 38/100
# 26/26 - 3s - 101ms/step - accuracy: 0.8469 - loss: 0.4486 - val_accuracy: 0.8222 - val_loss: 0.4842
# Epoch 39/100
# 26/26 - 3s - 102ms/step - accuracy: 0.8519 - loss: 0.4318 - val_accuracy: 0.8333 - val_loss: 0.4837
# Epoch 40/100
# 26/26 - 3s - 99ms/step - accuracy: 0.8667 - loss: 0.4299 - val_accuracy: 0.8111 - val_loss: 0.4722
# Epoch 41/100
# 26/26 - 3s - 103ms/step - accuracy: 0.8679 - loss: 0.4191 - val_accuracy: 0.8222 - val_loss: 0.4780
# Epoch 42/100
# 26/26 - 3s - 125ms/step - accuracy: 0.8519 - loss: 0.4493 - val_accuracy: 0.8222 - val_loss: 0.4692
# Epoch 43/100
# 26/26 - 3s - 118ms/step - accuracy: 0.8494 - loss: 0.4461 - val_accuracy: 0.8444 - val_loss: 0.4630
# Epoch 44/100
# 26/26 - 3s - 116ms/step - accuracy: 0.8605 - loss: 0.4121 - val_accuracy: 0.8111 - val_loss: 0.4686
# Epoch 45/100
# 26/26 - 5s - 196ms/step - accuracy: 0.8926 - loss: 0.3922 - val_accuracy: 0.8222 - val_loss: 0.4703
# Epoch 46/100
# 26/26 - 3s - 123ms/step - accuracy: 0.8716 - loss: 0.3915 - val_accuracy: 0.8333 - val_loss: 0.4555
# Epoch 47/100
# 26/26 - 3s - 106ms/step - accuracy: 0.8914 - loss: 0.3876 - val_accuracy: 0.8333 - val_loss: 0.4551
# Epoch 48/100
# 26/26 - 3s - 113ms/step - accuracy: 0.8802 - loss: 0.4071 - val_accuracy: 0.8333 - val_loss: 0.4452
# Epoch 49/100
# 26/26 - 3s - 126ms/step - accuracy: 0.8975 - loss: 0.3720 - val_accuracy: 0.8444 - val_loss: 0.4341
# Epoch 50/100
# 26/26 - 3s - 104ms/step - accuracy: 0.8963 - loss: 0.3763 - val_accuracy: 0.8444 - val_loss: 0.4311
# Epoch 51/100
# 26/26 - 3s - 116ms/step - accuracy: 0.8963 - loss: 0.3578 - val_accuracy: 0.8111 - val_loss: 0.4522
# Epoch 52/100
# 26/26 - 3s - 107ms/step - accuracy: 0.8975 - loss: 0.3744 - val_accuracy: 0.8444 - val_loss: 0.4347
# Epoch 53/100
# 26/26 - 3s - 111ms/step - accuracy: 0.9037 - loss: 0.3588 - val_accuracy: 0.8333 - val_loss: 0.4241
# Epoch 54/100
# 26/26 - 5s - 187ms/step - accuracy: 0.9086 - loss: 0.3517 - val_accuracy: 0.8556 - val_loss: 0.4259
# Epoch 55/100
# 26/26 - 3s - 103ms/step - accuracy: 0.8975 - loss: 0.3690 - val_accuracy: 0.8333 - val_loss: 0.4373
# Epoch 56/100
# 26/26 - 3s - 107ms/step - accuracy: 0.9148 - loss: 0.3435 - val_accuracy: 0.8556 - val_loss: 0.4114
# Epoch 57/100
# 26/26 - 3s - 108ms/step - accuracy: 0.9235 - loss: 0.3371 - val_accuracy: 0.8556 - val_loss: 0.4170
# Epoch 58/100
# 26/26 - 3s - 102ms/step - accuracy: 0.9272 - loss: 0.3172 - val_accuracy: 0.8667 - val_loss: 0.4045
# Epoch 59/100
# 26/26 - 3s - 102ms/step - accuracy: 0.9346 - loss: 0.3347 - val_accuracy: 0.8556 - val_loss: 0.4157
# Epoch 60/100
# 26/26 - 3s - 120ms/step - accuracy: 0.9148 - loss: 0.3371 - val_accuracy: 0.7667 - val_loss: 0.5191
# Epoch 61/100
# 26/26 - 5s - 187ms/step - accuracy: 0.9062 - loss: 0.3391 - val_accuracy: 0.8556 - val_loss: 0.4101
# Epoch 62/100
# 26/26 - 3s - 105ms/step - accuracy: 0.9148 - loss: 0.3315 - val_accuracy: 0.8667 - val_loss: 0.4023
# Epoch 63/100
# 26/26 - 3s - 105ms/step - accuracy: 0.9259 - loss: 0.3381 - val_accuracy: 0.8556 - val_loss: 0.4146
# Epoch 64/100
# 26/26 - 3s - 113ms/step - accuracy: 0.9370 - loss: 0.3085 - val_accuracy: 0.8667 - val_loss: 0.4005
# Epoch 65/100
# 26/26 - 3s - 105ms/step - accuracy: 0.9395 - loss: 0.2973 - val_accuracy: 0.8667 - val_loss: 0.3977
# Epoch 66/100
# 26/26 - 3s - 107ms/step - accuracy: 0.9333 - loss: 0.3044 - val_accuracy: 0.8556 - val_loss: 0.3999
# Epoch 67/100
# 26/26 - 3s - 104ms/step - accuracy: 0.9395 - loss: 0.2948 - val_accuracy: 0.8556 - val_loss: 0.3954
# Epoch 68/100
# 26/26 - 3s - 105ms/step - accuracy: 0.9358 - loss: 0.3021 - val_accuracy: 0.8556 - val_loss: 0.3982
# Epoch 69/100
# 26/26 - 3s - 106ms/step - accuracy: 0.9333 - loss: 0.3114 - val_accuracy: 0.8667 - val_loss: 0.3866
# Epoch 70/100
# 26/26 - 3s - 116ms/step - accuracy: 0.9543 - loss: 0.2794 - val_accuracy: 0.8556 - val_loss: 0.4036
# Epoch 71/100
# 26/26 - 5s - 181ms/step - accuracy: 0.9346 - loss: 0.2902 - val_accuracy: 0.8667 - val_loss: 0.3774
# Epoch 72/100
# 26/26 - 3s - 99ms/step - accuracy: 0.9444 - loss: 0.2803 - val_accuracy: 0.8667 - val_loss: 0.3729
# Epoch 73/100
# 26/26 - 3s - 105ms/step - accuracy: 0.9531 - loss: 0.2563 - val_accuracy: 0.8667 - val_loss: 0.3742
# Epoch 74/100
# 26/26 - 4s - 150ms/step - accuracy: 0.9506 - loss: 0.2733 - val_accuracy: 0.8778 - val_loss: 0.3634
# Epoch 75/100
# 26/26 - 3s - 122ms/step - accuracy: 0.9543 - loss: 0.2514 - val_accuracy: 0.8667 - val_loss: 0.3726
# Epoch 76/100
# 26/26 - 5s - 181ms/step - accuracy: 0.9556 - loss: 0.2583 - val_accuracy: 0.8889 - val_loss: 0.3581
# Epoch 77/100
# 26/26 - 7s - 264ms/step - accuracy: 0.9593 - loss: 0.2542 - val_accuracy: 0.8889 - val_loss: 0.3575
# Epoch 78/100
# 26/26 - 8s - 311ms/step - accuracy: 0.9494 - loss: 0.2545 - val_accuracy: 0.8889 - val_loss: 0.3658
# Epoch 79/100
# 26/26 - 8s - 296ms/step - accuracy: 0.9580 - loss: 0.2441 - val_accuracy: 0.8889 - val_loss: 0.3514
# Epoch 80/100
# 26/26 - 6s - 220ms/step - accuracy: 0.9642 - loss: 0.2425 - val_accuracy: 0.8778 - val_loss: 0.3513
# Epoch 81/100
# 26/26 - 6s - 235ms/step - accuracy: 0.9605 - loss: 0.2416 - val_accuracy: 0.8889 - val_loss: 0.3560
# Epoch 82/100
# 26/26 - 7s - 282ms/step - accuracy: 0.9654 - loss: 0.2310 - val_accuracy: 0.9000 - val_loss: 0.3419
# Epoch 83/100
# 26/26 - 5s - 200ms/step - accuracy: 0.9593 - loss: 0.2452 - val_accuracy: 0.8889 - val_loss: 0.3450
# Epoch 84/100
# 26/26 - 4s - 162ms/step - accuracy: 0.9605 - loss: 0.2385 - val_accuracy: 0.8778 - val_loss: 0.3522
# Epoch 85/100
# 26/26 - 4s - 148ms/step - accuracy: 0.9679 - loss: 0.2374 - val_accuracy: 0.8889 - val_loss: 0.3395
# Epoch 86/100
# 26/26 - 5s - 190ms/step - accuracy: 0.9654 - loss: 0.2285 - val_accuracy: 0.8667 - val_loss: 0.3678
# Epoch 87/100
# 26/26 - 4s - 171ms/step - accuracy: 0.9543 - loss: 0.2333 - val_accuracy: 0.8889 - val_loss: 0.3484
# Epoch 88/100
# 26/26 - 4s - 159ms/step - accuracy: 0.9691 - loss: 0.2281 - val_accuracy: 0.8778 - val_loss: 0.3333
# Epoch 89/100
# 26/26 - 4s - 162ms/step - accuracy: 0.9617 - loss: 0.2356 - val_accuracy: 0.9000 - val_loss: 0.3271
# Epoch 90/100
# 26/26 - 4s - 163ms/step - accuracy: 0.9568 - loss: 0.2153 - val_accuracy: 0.8889 - val_loss: 0.3348
# Epoch 91/100
# 26/26 - 4s - 147ms/step - accuracy: 0.9667 - loss: 0.2225 - val_accuracy: 0.8889 - val_loss: 0.3406
# Epoch 92/100
# 26/26 - 4s - 135ms/step - accuracy: 0.9642 - loss: 0.2265 - val_accuracy: 0.9000 - val_loss: 0.3298
# Epoch 93/100
# 26/26 - 5s - 188ms/step - accuracy: 0.9654 - loss: 0.2204 - val_accuracy: 0.8889 - val_loss: 0.3325
# Epoch 94/100
# 26/26 - 5s - 194ms/step - accuracy: 0.9691 - loss: 0.2164 - val_accuracy: 0.9111 - val_loss: 0.3134
# Epoch 95/100
# 26/26 - 5s - 173ms/step - accuracy: 0.9667 - loss: 0.2230 - val_accuracy: 0.8889 - val_loss: 0.3431
# Epoch 96/100
# 26/26 - 8s - 296ms/step - accuracy: 0.9691 - loss: 0.2109 - val_accuracy: 0.8889 - val_loss: 0.3369
# Epoch 97/100
# 26/26 - 7s - 282ms/step - accuracy: 0.9704 - loss: 0.2117 - val_accuracy: 0.8889 - val_loss: 0.3396
# Epoch 98/100
# 26/26 - 9s - 332ms/step - accuracy: 0.9667 - loss: 0.2179 - val_accuracy: 0.9000 - val_loss: 0.3278
# Epoch 99/100
# 26/26 - 5s - 201ms/step - accuracy: 0.9654 - loss: 0.1991 - val_accuracy: 0.8889 - val_loss: 0.3449
# Epoch 100/100
# 26/26 - 5s - 174ms/step - accuracy: 0.9679 - loss: 0.2017 - val_accuracy: 0.8778 - val_loss: 0.3552

# %%
#Duro 4 minutos aprox

# %%
# resumen del model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │     6,400,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,208,069 (73.27 MB)
#  Trainable params: 6,402,689 (24.42 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 12,805,380 (48.85 MB)

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)
# Out:
# 4/4 - 0s - 35ms/step - accuracy: 0.8400 - loss: 0.3833

# %%
# Obtén los datos del historial
accuracy = hist.history['accuracy']
val_accuracy = hist.history['val_accuracy']

loss = hist.history['loss']
val_loss = hist.history['val_loss']


# Gráfica de accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(accuracy, label='Train Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()

# Gráfica de pérdida
plt.subplot(1, 2, 2)
plt.plot(loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# Ajusta los márgenes y espacios entre subplots
plt.tight_layout()

# Muestra las gráficas
plt.show()

# %%
y_proba_train = model.predict(X_train)
y_pred_train = y_proba_train.round().astype(int)
y_proba_validation = model.predict(X_val)
y_pred_validation = y_proba_validation.round().astype(int)
y_proba_test = model.predict(X_test)
y_pred_test = y_proba_test.round().astype(int)
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
lbl = LabelEncoder()
target_names = ['class 0', 'class 1']
#Class 0 = NOK
#Class 1 = OK

# %%
# !pip install -q scikit-plot
import scikitplot as skplt

# %%
print("Train sample \n", classification_report(y_train, y_pred_train,target_names = target_names))
print("Validation sample \n", classification_report(y_val, y_pred_validation,target_names = target_names))
print("Test sample \n", classification_report(y_test, y_pred_test,target_names = target_names))
# Out:
# Train sample
#                precision    recall  f1-score   support
#
#      class 0       0.98      0.98      0.98       405
#      class 1       0.98      0.98      0.98       405
#
#     accuracy                           0.98       810
#    macro avg       0.98      0.98      0.98       810
# weighted avg       0.98      0.98      0.98       810
#
# Validation sample
#                precision    recall  f1-score   support
#
#      class 0       0.84      0.93      0.88        45
#      class 1       0.93      0.82      0.87        45
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90
#
# Test sample
#                precision    recall  f1-score   support
#
#      class 0       0.79      0.92      0.85        50
#      class 1       0.90      0.76      0.83        50
#
#     accuracy                           0.84       100
#    macro avg       0.85      0.84      0.84       100
# weighted avg       0.85      0.84      0.84       100

# %%
# Gráfico de Matriz de Confusión
skplt.metrics.plot_confusion_matrix(y_train, y_pred_train, normalize=True)
plt.title('Matriz de Confusión Train')

skplt.metrics.plot_confusion_matrix(y_val, y_pred_validation, normalize=True)
plt.title('Matriz de Confusión Validation')

skplt.metrics.plot_confusion_matrix(y_test, y_pred_test, normalize=True)
plt.title('Matriz de Confusión Test')

plt.show()

# %%
#taza de verdaderos positivos y taza de falsos positivos 
fpr, tpr, thresholds =  roc_curve(y_val, y_pred_validation)

#AUC 
auc = roc_auc_score(y_val, y_pred_validation)

plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Curva ROC (area = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taza de Falsos Positivos')
plt.ylabel('Taza de Verdaderos Positivos')
plt.title('Caracteristica Operativa del Receptor (CURVA ROC)\n Validacion')

plt.legend(loc="lower right")
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,5))

skplt.metrics.plot_roc(y_train, np.column_stack((1-y_pred_train, y_pred_train)), ax=axes[0])
axes[0].set_title("Muestra train")

skplt.metrics.plot_roc(y_test, np.column_stack((1-y_pred_test, y_pred_test)), ax=axes[1])
axes[1].set_title("Muestra test")

skplt.metrics.plot_roc(y_val, np.column_stack((1-y_pred_validation, y_pred_validation)), ax=axes[2])
axes[2].set_title("Muestra validation")
axes[2].legend(loc="lower right")

# %%
#calcular la curva pr
precision, recall, thresholds = precision_recall_curve(y_val, y_pred_validation)

auc_pr = average_precision_score(y_val, y_pred_validation)

plt.figure()
plt.plot(recall, precision, color='blue', lw=2, label=f'Curva Precision-Recall (area = {auc_pr:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Curva de Precision-Recall\n Validacion')

plt.legend(loc="lower right")
plt.show()

# %%
#guardar archivo de modelo ya entrenado
target_dir = './modelo_keras_noise4/'
if not os.path.exists(target_dir):
    os.mkdir(target_dir)
model.save('./modelo_keras_noise4/modelo_keras_noise4.keras')
model.save_weights('./modelo_keras_noise4/pesos.weights.h5')
